# %%
# %matplotlib inline
import numpy
import math
import matplotlib.pylab as plt
import seaborn;seaborn.set_context("poster")
from astropy import units as u
from astropy.coordinates import SkyCoord
from IPython.display import Latex

# %%
raliste1 = [38.75,39.25,39.25,39.25,39.75,39.75,39.75,39.75,39.75,40.25,40.25,40.25,40.25,40.75,40.75,40.75]
raliste2 = [89.75,90.25,90.25,90.25,90.75,90.75,90.75,91.25,91.25,91.25,92.25]
raliste3 = [120.25,120.25,120.75,120.75,120.75,121.25,121.25,121.25,121.75,121.75,121.75,122.75,122.25,122.25]
RA1 = numpy.array(raliste1)
RA2 = numpy.array(raliste2)
RA3 = numpy.array(raliste3)
RA1 = numpy.radians(RA1)
RA2 = numpy.radians(RA2)
RA3 = numpy.radians(RA3)
daliste1 = [18.75,18.25,18.75,19.25,17.75,18.25,18.75,19.25,19.75,17.75,18.25,18.75,19.25,18.25,18.75,19.25]
daliste2 = [11.75,10.75,11.25,11.75,10.75,11.25,1.75,10.25,10.75,11.25,18.75]
daliste3 = [12.25,12.75,11.75,12.25,12.75,11.75,12.25,12.75,11.75,12.25,12.75,13.25,12.75,12.75]
DA1 = numpy.array(daliste1)
DA2 = numpy.array(daliste2)
DA3 = numpy.array(daliste3)
DA1 = numpy.radians(DA1)
DA2 = numpy.radians(DA2)
DA3 = numpy.radians(DA3)

fig = plt.figure(figsize=(11,11))
ax = plt.subplot(111,projection="mollweide")
ax.grid(True)
ax.plot(RA1,DA1,'go',RA2,DA2,'bo',RA3,DA3,'ro',markersize=8,alpha=0.3)
plt.savefig('flaire.png',dpi=fig.dpi)
plt.show()

# %%
ns1 = [2.00442,1.99948,1.9994,1.99883,2.00309,1.9978,1.99931,1.99876,1.99983,2.00228,1.99919,1.99894,1.99842,1.99977,1.99903,1.99948]
logp1 = [1.163565,1.49012,1.58561,1.376,1.23863,1.640315,1.735755,1.524045,1.012905,1.11394,1.513235,1.6095,1.399245,1.115395,1.210875,1.00587]
ns2 = [1.99998,2,2.00011,1.99997,1.99996,1.99999,1.99998,1.99993,2.00008,1.99998]
logp2 = [0.85336,1.00166,1.01285,0.946345,1.0208,1.03194,0.96528,0.876545,0.96488,0.9761]
ns3 = [1.99998,1.99998,1.99998,2,2,1.99998,2,2,1.99998,1.99999,1.99999,1.99998,1.99998,1.99998]
logp3 = [1.02221,1.10928,0.98215,1.365215,1.453305,1.04192,1.4262,1.51439,0.823365,1.202415,1.290085,1.081145,0.57067,0.791635]
ns1  = numpy.array(ns1)
ns2  = numpy.array(ns2)
ns3  = numpy.array(ns3)
logp1  = numpy.array(logp1)
logp2  = numpy.array(logp2)
logp3  = numpy.array(logp3)
fig = plt.figure(figsize=(11,11))
ax = plt.subplot(111,)
ax.set_xlabel("$-Log_{10}p$",fontsize=25)
ax.set_ylabel("$\hat{n}_s$",fontsize=25)
ax.grid()
ax.plot(logp1,ns1,'go',logp2,ns2,'bo',logp3,ns3,'ro',markersize=10,alpha=0.5)
plt.savefig('nsvslogp.png',dpi=fig.dpi)
plt.show()

# %%
ns1 = [2.00442,1.99948,1.9994,1.99883,2.00309,1.9978,1.99931,1.99876,1.99983,2.00228,1.99919,1.99894,1.99842,1.99977,1.99903,1.99948]
ns2 = [1.99998,2,2.00011,1.99997,1.99996,1.99999,1.99998,1.99993,2.00008,1.99998]
ns3 = [1.99998,1.99998,1.99998,2,2,1.99998,2,2,1.99998,1.99999,1.99999,1.99998,1.99998,1.99998]
sigma1 = [1.035914096,1.044152043,1.045066057,1.043358942,1.028380286,1.049841515,1.05743515,1.061167016,1.03372196,1.029707183,1.049044093,1.059604374,1.051535024,1.030608553,1.043022657,1.040144657]
sigma2 = [2.562381219,2.56285327,2.560729723,2.561850265,2.572549514,2.562971297,2.570654688,2.56362054,2.56651462,2.566160067]
sigma3 = [4.492455072,4.485219922,4.481090783,4.466977269,4.463378761,4.493282689,4.464715011,4.463481535,4.464509408,4.472123028,4.463995442,4.46522906,4.470166942,4.46522906]
ns1  = numpy.array(ns1)
ns2  = numpy.array(ns2)
ns3  = numpy.array(ns3)
sigma1  = numpy.array(sigma1)
sigma2  = numpy.array(sigma2)
sigma3  = numpy.array(sigma3)
fig = plt.figure(figsize=(11,11))
ax = plt.subplot(111,)
ax.set_xlabel(r"$\hat{\sigma}_T(s)$",fontsize=25)
ax.set_ylabel("$\hat{n}_s$",fontsize=25)
ax.grid()
ax.plot(sigma1,ns1,'go',sigma2,ns2,'bo',sigma3,ns3,'ro',markersize=10,alpha=0.5)
plt.savefig('nsvsigmap.png',dpi=fig.dpi)
plt.show()

# %%
mean1 =[56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9,56744.9]
mean2 =[56857.4,56857.4,56857.4,56857.4,56857.4,56857.4,56857.4,56857.4,56857.4,56857.4]
mean3 = [56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2,56665.2]
logp1 = [1.163565,1.49012,1.58561,1.376,1.23863,1.640315,1.735755,1.524045,1.012905,1.11394,1.513235,1.6095,1.399245,1.115395,1.210875,1.00587]
logp2 = [0.85336,1.00166,1.01285,0.946345,1.0208,1.03194,0.96528,0.876545,0.96488,0.9761]
logp3 = [1.02221,1.10928,0.98215,1.365215,1.453305,1.04192,1.4262,1.51439,0.823365,1.202415,1.290085,1.081145,0.57067,0.791635]
mean1  = numpy.array(mean1)
mean2  = numpy.array(mean2)
mean3  = numpy.array(mean3)
logp1  = numpy.array(logp1)
logp2  = numpy.array(logp2)
logp3  = numpy.array(logp3)
fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111,)
ax.set_xlabel("$-Log_{10}p$",fontsize=25)
ax.set_ylabel("$\hat{T}_0 (MJD)$",fontsize=25)
ax.grid()
ax.plot(logp1,mean1,'go',logp2,mean2,'bo',logp3,mean3,'ro',markersize=10,alpha=0.5)
plt.savefig('meanvslogp.png',dpi=fig.dpi)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)
E = numpy.logspace(-1,6,51)
phi1 = 0.311915*E**(-2)
phi2 = 0.124766*E**-2
phi3 = 0.0693145*E**-2
ax.plot(E,phi1,'g-',phi2,'b-',phi3,'r-')
ax.grid()
plt.savefig('flux.png',dpi=fig.dpi)
plt.show()
